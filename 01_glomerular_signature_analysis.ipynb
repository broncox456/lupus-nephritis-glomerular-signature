# %%
# Lupus Nephritis Glomerular Signature

Reproducible transcriptomics workflow based on GEO dataset GSE32591.

## Clinical focus
Glomerular lupus nephritis versus control glomerular tissue.

## Methods
- R: GEOquery + limma
- Python: prioritization and plotting
# Out:
#   Cell In[3], line 3
#     Reproducible transcriptomics workflow based on GEO dataset GSE32591.
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
deg = pd.read_csv("../results/tables/ln_glomerular_limma_results.tsv", sep="\t")
deg.head()

# %%
## Summary metrics
The table below reports the total number of tested features and the number of significant features at FDR < 0.05.

# %%
summary = pd.read_csv("../results/tables/ln_glomerular_summary_metrics.tsv", sep="\t")
summary

# %%
## Top prioritized genes
Genes were ranked using a simple score combining absolute log fold change and adjusted p-value.

# %%
top20 = pd.read_csv("../results/tables/ln_glomerular_top20.tsv", sep="\t")
top20

# %%
## top upregulated genes

# %%
top_up = pd.read_csv("../results/tables/ln_glomerular_top10_up.tsv", sep="\t")
top_up

# %%
## top downregulated genes

# %%
top_down = pd.read_csv("../results/tables/ln_glomerular_top10_down.tsv", sep="\t")
top_down

# %%
## Volcano plot
The figure below summarizes differential expression in glomerular lupus nephritis versus control samples.

# %%
from IPython.display import Image
Image(filename="../results/figures/volcano_plot.png")

# %%
## Interpretation
The top-ranked genes are consistent with interferon signaling and immune activation, which is biologically plausible in lupus nephritis.
